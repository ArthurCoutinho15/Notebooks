# %%
clientes = np.array([[1, 'João', 30, 'Rua A', 100, 'eletrônicos'],
                     [2, 'Maria', 25, 'Rua B', 200, 'moda'],
                     [3, 'Pedro', 35, 'Rua C', 50, 'esportes']])

clientes

# %%
d = clientes[:,4:6]
d

# %% [markdown]
# Importando csv laranjas

# %%
import numpy as np

dado = np.loadtxt('citrus.csv',delimiter=',',usecols=np.arange(1,6,1), skiprows=1)

dado
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
diametro_laranja = dado[:5000,0]
diametro_toranja = dado[5000:,0]
peso_laranja = dado[:5000,1]
peso_toranja = dado[5000:,1]

diametro_laranja
# Out:
# array([ 2.96,  3.91,  4.42, ..., 12.55, 12.75, 12.87])

# %%
import matplotlib.pyplot as plt

plt.plot(diametro_laranja, peso_laranja)
plt.plot(diametro_toranja, peso_toranja)
plt.legend(['laranja','toranja'])

# %% [markdown]
# Desenhando Círculo:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerar uma sequência de valores de x de -1 a 1
x = np.arange(-1, 1.01, 0.0001)

# Implementação da fórmula
y1 = np.sqrt(1 - x**2)
y2 = -np.sqrt(1 - x**2)

# Plotar o gráfico com as duas partes do círculo
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'r' )

# Adicionar o título do gráfico e os rótulos dos eixos x e y
plt.title("Círculo")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\Arthur Coutinho\AppData\Local\Temp\ipykernel_6172\2529242494.py:8: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(1 - x**2)
# C:\Users\Arthur Coutinho\AppData\Local\Temp\ipykernel_6172\2529242494.py:9: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -np.sqrt(1 - x**2)
